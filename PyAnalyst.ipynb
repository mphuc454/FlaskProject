# %% [markdown]
# Sentiment Analysis
# Thuật toán	Mục đích
# Naive Bayes	Baseline cho text classification
# Logistic Regression	So sánh accuracy với NB
# SVM	Thường accuracy cao cho NLP
# Decision Tree	So sánh mô hình cây
# Random Forest	Ensemble learning
# KNN	So sánh distance-based model

# %% [markdown]
# 3. Thuật toán Deep Learning để so sánh thêm
# Thuật toán	Đặc điểm
# RNN	Đọc chuỗi tuần tự
# LSTM	Nhớ context tốt hơn RNN
# GRU	Nhẹ hơn LSTM
# CNN for NLP	Trích đặc trưng câu
# BERT	Transformer hiện đại

# %% [markdown]
# 2. Feature Extraction dùng kèm
#
# Các model ML không đọc text trực tiếp nên cần biến text thành vector.
#
# Các kỹ thuật phổ biến
# Kỹ thuật	Ý nghĩa
# Bag of Words (BoW)	Đếm số lần xuất hiện từ
# TF-IDF	Độ quan trọng của từ
# Word2Vec	Vector ngữ nghĩa
# CountVectorizer	Chuyển text thành ma trận số

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
